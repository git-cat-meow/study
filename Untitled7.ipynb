# %% [markdown]
# <a href="https://colab.research.google.com/github/git-cat-meow/study/blob/master/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# knock1
import pandas as pd
customer_master = pd.read_csv('/content/drive/My Drive/sample_100knocks.zip (Unzipped Files)/ƒTƒ“ƒvƒ‹ƒR[ƒh_20200325/1Í/customer_master.csv')
display(customer_master.head(15))
display(customer_master.info())

item_master = pd.read_csv('/content/drive/My Drive/sample_100knocks.zip (Unzipped Files)/ƒTƒ“ƒvƒ‹ƒR[ƒh_20200325/1Í/item_master.csv')
item_master # とりあえず外観だけチェック

transaction_1 = pd.read_csv('/content/drive/My Drive/sample_100knocks.zip (Unzipped Files)/ƒTƒ“ƒvƒ‹ƒR[ƒh_20200325/1Í/transaction_1.csv')
transaction_1

transaction_detail_1 = pd.read_csv('/content/drive/My Drive/sample_100knocks.zip (Unzipped Files)/ƒTƒ“ƒvƒ‹ƒR[ƒh_20200325/1Í/transaction_detail_1.csv')
transaction_detail_1
# Out:
#    customer_id customer_name    registration_date  ... age       birth  pref
# 0     IK152942        平田 裕次郎  2019-01-01 00:25:33  ...  29   1990/6/10   石川県
# 1     TS808488         田村 詩織  2019-01-01 01:13:45  ...  33   1986/5/20   東京都
# 2     AS834628         久野 由樹  2019-01-01 02:00:14  ...  63    1956/1/2   茨城県
# 3     AS345469          鶴岡 薫  2019-01-01 04:48:22  ...  74   1945/3/25   東京都
# 4     GD892565         大内 高史  2019-01-01 04:54:51  ...  54    1965/8/5   千葉県
# 5     AS265381         笠井 洋介  2019-01-01 05:51:07  ...  69    1949/8/9   岡山県
# 6     HD739338         橋口 将也  2019-01-01 05:51:08  ...  45    1974/6/4  神奈川県
# 7     HI791416        細井 麻由子  2019-01-01 07:03:53  ...  30   1989/7/25   三重県
# 8     HD819739        塩見 はるか  2019-01-01 08:17:23  ...  49   1969/10/8  神奈川県
# 9     OA239766        玉木 有起哉  2019-01-01 08:59:29  ...  22   1997/1/12   東京都
# 10    HD743252         阿部 鉄洋  2019-01-01 15:13:38  ...  51   1967/11/8   福岡県
# ...

# %%
# knock2

transaction_2 = pd.read_csv('/content/drive/My Drive/sample_100knocks.zip (Unzipped Files)/ƒTƒ“ƒvƒ‹ƒR[ƒh_20200325/1Í/transaction_2.csv')
transaction = pd.concat([transaction_1, transaction_2], ignore_index=True)
# indexになるとややこしいのでそのままにする
# concatするときは変数（DF）同士なのでコーテーションで囲む必要はない

transaction.head()

# 検算が大事
print(len(transaction_1))
print(len(transaction_2))
print(len(transaction))
print(len(transaction_1)+len(transaction_2))

# 残りも結合
transaction_detail_2 = pd.read_csv('/content/drive/My Drive/sample_100knocks.zip (Unzipped Files)/ƒTƒ“ƒvƒ‹ƒR[ƒh_20200325/1Í/transaction_detail_2.csv')
transaction_detail = pd.concat([transaction_detail_1, transaction_detail_2], ignore_index=True)
transaction_detail

# 検算が大事
print(len(transaction_detail_1))
print(len(transaction_detail_2))
print(len(transaction_detail))
print(len(transaction_detail_1)+len(transaction_detail_2))
# Out:
# 5000
# 1786
# 6786
# 6786
# 5000
# 2144
# 7144
# 7144

# %%
# knock3

print("transaction_detail")
display(transaction_detail.head(10))

print("transaction")
display(transaction.head(10))

join_data = pd.merge(transaction_detail, transaction[['transaction_id', "payment_date", "customer_id"]], on="transaction_id", how="left")
# mergeする際はmergeしたデータが増えていないか注意。キーがユニークでない場合はデータが増える

print("join_data")
join_data

# 検算が大事
print(len(transaction_detail))
print(len(transaction))
print(len(join_data))
# Out:
# transaction_detail
#    detail_id transaction_id item_id  quantity
# 0          0    T0000000113    S005         1
# 1          1    T0000000114    S001         1
# 2          2    T0000000115    S003         1
# 3          3    T0000000116    S005         1
# 4          4    T0000000117    S002         2
# 5          5    T0000000118    S003         1
# 6          6    T0000000119    S004         1
# 7          7    T0000000120    S001         1
# 8          8    T0000000121    S005         1
# 9          9    T0000000122    S002         1
# transaction
#   transaction_id   price         payment_date customer_id
# 0    T0000000113  210000  2019-02-01 01:36:57    PL563502
# 1    T0000000114   50000  2019-02-01 01:37:23    HD678019
# 2    T0000000115  120000  2019-02-01 02:34:19    HD298120
# 3    T0000000116  210000  2019-02-01 02:47:23    IK452215
# 4    T0000000117  170000  2019-02-01 04:33:46    PL542865
# 5    T0000000118  120000  2019-02-01 04:36:50    GD372798
# ...
